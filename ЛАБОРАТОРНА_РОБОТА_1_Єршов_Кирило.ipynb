# %% [markdown]
# <a href="https://colab.research.google.com/github/ErshovKirill/KCVD/blob/main/%D0%9B%D0%90%D0%91%D0%9E%D0%A0%D0%90%D0%A2%D0%9E%D0%A0%D0%9D%D0%90_%D0%A0%D0%9E%D0%91%D0%9E%D0%A2%D0%90_1_%D0%84%D1%80%D1%88%D0%BE%D0%B2_%D0%9A%D0%B8%D1%80%D0%B8%D0%BB%D0%BE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
'''1. Побудувати рекурентну нейронну мережу для прогнозування слів.
 Підібрати архітектуру моделі, кількість  і тип рекурентних шарів, гіперпараметри моделі.
 Побудувати графіки функції втрат і точності.
 Також доцільно викоритстати Керас тюнер для підбору параметрів. '''

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, LSTM, Embedding, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical

# Текст для навчання
texts = """
Страшні слова, коли вони мовчать,
коли вони зненацька причаїлись,
коли не знаєш, з чого їх почать,
бо всі слова були уже чиїмись.

Хтось ними плакав, мучивсь, болів,
із них почав і ними ж і завершив.
Людей мільярди і мільярди слів,
а ти їх маєш вимовити вперше!

Все повторялось: і краса, й потворність.
Усе було: асфальти й спориші.
Поезія — це завжди неповторність,
якийсь безсмертний дотик до душі.
"""

# Попередня обробка тексту
texts = texts.replace('\ufeff', '')
maxWordsCount = 500  # Зменшимо розмір словника

tokenizer = Tokenizer(num_words=maxWordsCount, filters='"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r', lower=True)
tokenizer.fit_on_texts([texts])

data = tokenizer.texts_to_sequences([texts])
res = np.array(data[0])

inp_words = 3
n = res.shape[0] - inp_words

# Формуємо навчальні вибірки
X = np.array([res[i:i + inp_words] for i in range(n)])
Y = to_categorical(res[inp_words:], num_classes=maxWordsCount)

# Побудова моделі
model = Sequential()
model.add(Embedding(maxWordsCount, 128))  # Менший Embedding
model.add(LSTM(64, return_sequences=False))  # Один LSTM-шар
model.add(Dropout(0.3))  # Dropout для регуляризації
model.add(Dense(maxWordsCount, activation='softmax'))  # Вихідний шар

# Компільовуємо модель
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# Навчання моделі
history = model.fit(X, Y, batch_size=16, epochs=50)

# Графіки функції втрат та точності
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Графік функції втрат')

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Графік точності')

plt.show()

# Вивід архітектури моделі
model.summary()

# Функція генерації тексту з температурним семплінгом
def buildPhrase(texts, str_len=20, temperature=1.0):
    res = texts
    data = tokenizer.texts_to_sequences([texts])[0]

    for _ in range(str_len):
        x = np.array([data[-inp_words:]])
        pred = model.predict(x)[0]
        pred = np.log(pred + 1e-8) / temperature
        exp_preds = np.exp(pred)
        pred_probs = exp_preds / np.sum(exp_preds)
        indx = np.random.choice(range(maxWordsCount), p=pred_probs)

        data.append(indx)
        res += " " + tokenizer.index_word.get(indx, '')

    return res

# Генерація нового тексту
res = buildPhrase("Страшні слова, коли вони", str_len=20, temperature=0.8)
print(res)
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0167 - loss: 6.2149
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1042 - loss: 6.2055
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2208 - loss: 6.1946
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2583 - loss: 6.1842
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4062 - loss: 6.1730
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4354 - loss: 6.1559
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3125 - loss: 6.1413
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2917 - loss: 6.1198
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3896 - loss: 6.0891
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2042 - loss: 6.0463
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2250 - loss: 5.9946
# Epoch 12/50
# ...

# %%
# !pip install keras-tuner
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.6 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras_tuner as kt
from tensorflow.keras.layers import Dense, GRU, LSTM, Embedding, Dropout, Bidirectional, SimpleRNN
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical

# Текст для навчання
texts = """
Страшні слова, коли вони мовчать,
коли вони зненацька причаїлись,
коли не знаєш, з чого їх почать,
бо всі слова були уже чиїмись.

Хтось ними плакав, мучивсь, болів,
із них почав і ними ж і завершив.
Людей мільярди і мільярди слів,
а ти їх маєш вимовити вперше!

Все повторялось: і краса, й потворність.
Усе було: асфальти й спориші.
Поезія — це завжди неповторність,
якийсь безсмертний дотик до душі.
"""

# Попередня обробка тексту
texts = texts.replace('\ufeff', '')
maxWordsCount = 1000
tokenizer = Tokenizer(num_words=maxWordsCount, filters='1-"-#$%&; ()*+,-./:; <=>?@[\\]^_{}}~\t\n\r',
                      lower=True, split=' ', char_level=False)
tokenizer. fit_on_texts([texts])

#Перетворюємо текст у числову послідовність
data = tokenizer.texts_to_sequences ([texts])
res = np.array(data[0])

inp_words = 3 # Кількість слів у вхідній послідовності
n = res.shape[0] - inp_words

# Формуємо навчальні вибірки
X = np.array([res[i:i + inp_words] for i in range(n)])
Y = to_categorical (res [inp_words: ], num_classes=maxWordsCount)


# Функція для створення моделі (HyperModel)
def build_model(hp):
    model = Sequential()
    model.add(Embedding (maxWordsCount, hp. Int('embedding_dim', 128, 512, step=64), input_length=inp_words))
    model.add(SimpleRNN(hp.Int('rnn_units', 64, 256, step=64), activation= 'tanh', return_sequences=True))
    model.add(LSTM(hp.Int('1stm_units', 64, 256, step=64), activation= 'tanh'))
    model.add(Dropout (hp. Float('dropout_rate', 0.1, 0.5, step=0.1)))
    model.add(Dense (hp. Int('dense_units', 64, 256, step=64), activation= 'relu'))
    model.add(Dense (maxWordsCount, activation='softmax'))

    model.compile(
    loss='categorical_crossentropy',
    metrics=['accuracy'],
    optimizer=hp.Choice('optimizer', ['adam', 'rmsprop'])
    )
    return model


# Використання Keras Tuner
tuner = kt.RandomSearch(
    build_model,
    objective='accuracy',
    max_trials=10,
    executions_per_trial=1,
    directory='my_tuning',
    project_name='text_prediction'
)
# Запуск підбору параметрів
tuner.search(X, Y, epochs=10, batch_size=32)

# Отримуємо найкращі параметри
best_hps = tuner.get_best_hyperparameters (num_trials=1)[0]
print(f"""
Найкращі параметри:
Embedding Dimension: {best_hps.get('embedding_dim')}
RNN Units: {best_hps.get('rnn_units')}
LSTM Units: {best_hps.get('1stm_units')}
Dropout Rate: {best_hps.get('dropout_rate')}
Dense Units: {best_hps.get('dense_units')}
Optimizer: {best_hps.get('optimizer')} """)

# Будуємо модель з найкращими параметрами
best_model = tuner.hypermodel.build(best_hps)

# Навчаємо модель з найкращими параметрами
history = best_model.fit(X, Y, batch_size=32, epochs=50)


# Графіки функції втрат та точності
plt.figure(figsize=(12, 4))

# Графік втрат
plt.subplot(1, 2, 1)
plt.plot (history.history['loss'], label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Графік функції втрат')


# Графік точності
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Графік точності')

plt.show()

# Вивід архітектури моделі
best_model.summary()

# Функція для генерації тексту
def buildPhrase (texts, str_len=20):
    res = texts
    data = tokenizer.texts_to_sequences([texts])[0]
    for i in range(str_len):
        x = data[i: i + inp_words]
        inp = np.expand_dims (x, axis=0)

        pred = best_model.predict(inp)
        indx= pred. argmax(axis=1)[0]
        data.append(indx)

        res += " " + tokenizer.index_word.get(indx, '')
    return res

#Генерація нового тексту
res = buildPhrase("Страшні слова, коли вони")
print(res)
# Out:
# Trial 10 Complete [00h 00m 06s]
# accuracy: 0.125
#
# Best accuracy So Far: 0.65625
# Total elapsed time: 00h 01m 04s
#
# Найкращі параметри:
# Embedding Dimension: 256
# RNN Units: 192
# LSTM Units: 256
# Dropout Rate: 0.1
# Dense Units: 192
# Optimizer: adam
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.0208 - loss: 6.9070
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3229 - loss: 6.8898
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4271 - loss: 6.8680
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4479 - loss: 6.8342
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2604 - loss: 6.7782
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.1250 - loss: 6.6607
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.0625 - loss: 6.4091
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.0625 - loss: 5.8500
# Epoch 9/50
# ...

# %%
'''
У першому коді (без Keras Tuner) надто низька точність. і хоч я кілька разів
змінював моделі та кількість шарів, це не надто вплинуло на результат. Там велика
втрата хоч вона й знижувалася, залишалася на рівні ~3.07 наприкінці навчання.
На відміну від другого виконання коду. Краща точність: найкраще значення ~65%,
що значно вище початкової моделі. Також менша втрата та Оптимізовані гіперпараметри
'''
# Out:
# '\nУ першому коді (без Keras Tuner) надто низька точність. і хоч я кілька разів\nзмінював моделі та кількість шарів, це не надто вплинуло на результат. Там велика\nвтрата хоч вона й знижувалася, залишалася на рівні ~3.07 наприкінці навчання.\nНа відміну від другого виконання коду. Краща точність: найкраще значення ~65%,\nщо значно вище початкової моделі. Також менша втрата та Оптимізовані гіперпараметри\n'
